# %% [markdown]
# # Agregar y Eliminar
# ```sh
# # Eliminar
# # Metodo 1
# df.drop('Genre', axis=1, inplace=True)
# # Metodo 2
# df = df.drop('Year', axis=1)
# # Metodo 3
# del df['Price']
# # Borrar columnas
# df.drop(0, axis=0, inplace=True)
# ```
# ```sh
# # Agregar valores
# df['New Column'] = np.nan
# # Valor del shape
# df.shape[0]
# df['New Column 2'] = np.random.randint(0, 10, df.shape[0])
# # Agregar filas
# df.append(df)
# ```

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./assts/bestsellers-with-categories.csv')
df.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
# Eliminar 
# Metodo 1
df.drop('Genre', axis=1, inplace=True)
df.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
# Metodo 2
df = df.drop('Year', axis=1)
df.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22

# %%
# Metodo 3
#del df['Price']
df.head(2)
# Out:
#                             Name        Author  User Rating  Reviews
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350
# 1              11/22/63: A Novel  Stephen King          4.6     2052

# %%
# Borrar columnas
df.drop(0, axis=0, inplace=True)
df.head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews
# 1     2052
# 2    18979

# %%
#df.drop([1,2,3], axis=0).head(3)
df.drop(range(1,10), axis=0).head(3)
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
# 12                            A Stolen Life: A Memoir     Jaycee Dugard
#
#     User Rating  Reviews
# 10          4.6    23848
# 11          4.6      460
# 12          4.6     4149

# %% [markdown]
# # Agregar

# %%
df.head(5)
# Out:
#                                                 Name  \
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews
# 1              Stephen King          4.6     2052
# 2        Jordan B. Peterson          4.7    18979
# 3             George Orwell          4.7    21424
# 4  National Geographic Kids          4.8     7665
# 5       George R. R. Martin          4.4    12643

# %%
df['New Column'] = np.nan
df
# Out:
#                                                   Name  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  New Column
# 1                Stephen King          4.6     2052         NaN
# 2          Jordan B. Peterson          4.7    18979         NaN
# 3               George Orwell          4.7    21424         NaN
# ...

# %%
# Indica cuantos registros se tiene
df.shape[0]
df['New Column 2'] = np.random.randint(0, 10, df.shape[0])
df['New Column 3'] = np.arange(0, df.shape[0])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Indica cuantos registros se tiene
# ----> 2 df.shape[0]
#       3 df['New Column 2'] = np.random.randint(0, 10, df.shape[0])
#       4 df['New Column 3'] = np.arange(0, df.shape[0])
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Agregar filas

# %%
df.append(df)
df
# Out:
# /tmp/ipykernel_19671/1723972856.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df)
#                                                   Name  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  New Column  New Column 2  \
# ...
